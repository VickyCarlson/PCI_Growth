# %%
#Please read readME.md in Databases folder to set up connection
#Must have pgadmin/postgres set up. Note the password you use to connect to database
from sqlalchemy import create_engine
from config import db_password
import pandas as pd
##Must create config.py file with db_password = YourPassword for this to work. 
##Check gitignore includes .py files. Do not commit config.py. Check with git status
##Must match name of your database (FinalProject)
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/FinalProject"

# %%
#Create database engine
engine = create_engine(db_string)
#Error message? Uncomment and run the following cell, then re-run this one

# %%
#pip install psycopg2-binary

# %%
#Import input data
inputDf = pd.read_csv("../Resources/cleaned_education_new.csv")

#Set index as year to get rid of unnecessary index col.
inputDf = inputDf.set_index(["State"])
inputDf.head()
# Out:
#             YEAR  Less_than_9th_ grade  9th_to_12th_grade_no_diploma  \
# State
# Alabama     2019                130320                        302753
# Alaska      2019                 10424                         20666
# Arizona     2019                252459                        360539
# Arkansas    2019                 94376                        160617
# California  2019               2346235                       1955278
#
#             High_school_graduate_(includes_equivalency)  \
# State
# Alabama                                         1039241
# Alaska                                           139156
# Arizona                                         1170685
# Arkansas                                         710306
# California                                      5546711
#
#             Some_college,_no_degree  Associates_degree  Bachelors_degree  \
# State
# Alabama                      700473             301914            547975
# ...

# %%
#Import output data
outputDf = pd.read_csv("../Resources/Personal Income.csv")

#Set index as GeoName to get rid of unnecessary index col.
outputDf = outputDf.set_index(["GeoName"])
outputDf.head()
# Out:
#                                        Description       1998        1999  \
# GeoName
# Alabama     Personal income (thousands of dollars)   99847704   103369398
# Alaska      Personal income (thousands of dollars)   18136011    18712485
# Arizona     Personal income (thousands of dollars)  118042927   125393478
# Arkansas    Personal income (thousands of dollars)   55698439    57999091
# California  Personal income (thousands of dollars)  959693523  1030884656
#
#                   2000        2001        2002        2003        2004  \
# GeoName
# Alabama      108215370   111947357   114904537   120123434   128828691
# Alaska        20122417    21309233    22325307    23340268    24404323
# Arizona      136175114   142423527   147602212   156458313   170821628
# Arkansas      61020960    64255331    65770417    69742263    74404831
# California  1135543382  1173878608  1190223778  1243465494  1318744308
#
# ...

# %%
# Turn Dataframes to sql using engine created above.
# Put data into tables inputData and outputData
inputDf.to_sql(name="inputdata", con=engine)
outputDf.to_sql(name="outputdata", con=engine)

#You should now have data in these two tables!
#Check with pgAdmin. Schema > Tables (be sure to refresh) > Right click table names and view data
